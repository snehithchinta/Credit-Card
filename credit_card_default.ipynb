# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
! pip install datasets transformers rouge-score nltk

import numpy as np
import pandas as pd
from sklearn import datasets
# Out:
# ...
#      |████████████████████████████████| 264 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 7.4 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 25.9 MB/s
# ...
#      |████████████████████████████████| 118 kB 30.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 30.9 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 32.1 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
df_testing = pd.read_csv("/content/drive/MyDrive/dataset/test.csv")
df_training = pd.read_csv("/content/drive/MyDrive/dataset/train.csv")

# %%
df_train=df_training[["Id","income","age","experience","profession","state","house_ownership","married","car_ownership","current_job_years","current_house_years"]]
df_train_output=df_training["risk_flag"]

# %%
df_train["married"] = df_train["married"].replace('married', 1)
df_train["married"] = df_train["married"].replace('single', 0)
df_train["house_ownership"] = df_train["house_ownership"].replace('owned', 1)
df_train["house_ownership"] = df_train["house_ownership"].replace('rented', 0)
df_train["car_ownership"] = df_train["car_ownership"].replace('no', 0)
df_train["car_ownership"] = df_train["car_ownership"].replace('yes', 1)
df_train["house_ownership"]=df_train["house_ownership"].replace('norent_noown',2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train["profession"]=df_train["profession"].replace('Statistician',0)
df_train["profession"]=df_train["profession"].replace('Physician',1)
df_train["profession"]=df_train["profession"].replace('Psychologist',2)
df_train["profession"]=df_train["profession"].replace('Graphic_Designer',3)
df_train["profession"]=df_train["profession"].replace('Industrial_Engineer',4)
df_train["profession"]=df_train["profession"].replace('Computer_hardware_engineer',5)
df_train["profession"]=df_train["profession"].replace('Flight_attendant',6)
df_train["profession"]=df_train["profession"].replace('Financial_Analyst',7)
df_train["profession"]=df_train["profession"].replace('Web_designer',8)
df_train["profession"]=df_train["profession"].replace('Mechanical_engineer',9)
df_train["profession"]=df_train["profession"].replace('Magistrate',10)
df_train["profession"]=df_train["profession"].replace('Chemical_engineer',11)
df_train["profession"]=df_train["profession"].replace('Comedian',12)
df_train["profession"]=df_train["profession"].replace('Drafter',13)
df_train["profession"]=df_train["profession"].replace('Biomedical_Engineer',14)
df_train["profession"]=df_train["profession"].replace('Fashion_Designer',15)
df_train["profession"]=df_train["profession"].replace('Hotel_Manager',16)
df_train["profession"]=df_train["profession"].replace('Software_Developer',17)
df_train["profession"]=df_train["profession"].replace('Police_officer',18)
df_train["profession"]=df_train["profession"].replace('Technical_writer',19)
df_train["profession"]=df_train["profession"].replace('Petroleum_Engineer',20)
df_train["profession"]=df_train["profession"].replace('Air_traffic_controller',21)
df_train["profession"]=df_train["profession"].replace('Artist',22)
df_train["profession"]=df_train["profession"].replace('Politician',23)
df_train["profession"]=df_train["profession"].replace('Microbiologist',24)
df_train["profession"]=df_train["profession"].replace('Secretary',25)
df_train["profession"]=df_train["profession"].replace('Computer_operator',26)
df_train["profession"]=df_train["profession"].replace('Surgeon',27)
df_train["profession"]=df_train["profession"].replace('Consultant',28)
df_train["profession"]=df_train["profession"].replace('Aviator',29)
df_train["profession"]=df_train["profession"].replace('Lawyer',30)
df_train["profession"]=df_train["profession"].replace('Design_Engineer',31)
df_train["profession"]=df_train["profession"].replace('Scientist',32)
df_train["profession"]=df_train["profession"].replace('Librarian',33)
df_train["profession"]=df_train["profession"].replace('Architect',34)
df_train["profession"]=df_train["profession"].replace('Technician',35)
df_train["profession"]=df_train["profession"].replace('Chef',36)
df_train["profession"]=df_train["profession"].replace('Technology_specialist',37)
df_train["profession"]=df_train["profession"].replace('Geologist',38)
df_train["profession"]=df_train["profession"].replace('Army_officer',39)
df_train["profession"]=df_train["profession"].replace('Economist',40)
df_train["profession"]=df_train["profession"].replace('Dentist',41)
df_train["profession"]=df_train["profession"].replace('Designer',42)
df_train["profession"]=df_train["profession"].replace('Surveyor',43)
df_train["profession"]=df_train["profession"].replace('Analyst',44)
df_train["profession"]=df_train["profession"].replace('Chartered_Accountant',45)
df_train["profession"]=df_train["profession"].replace('Firefighter',46)
df_train["profession"]=df_train["profession"].replace('Civil_servant',47)
df_train["profession"]=df_train["profession"].replace('Official',48)
df_train["profession"]=df_train["profession"].replace('Civil_engineer',49)
df_train["profession"]=df_train["profession"].replace('Engineer',50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train["state"]=df_train["state"].replace('Uttar_Pradesh',0)
df_train["state"]=df_train["state"].replace('Andhra_Pradesh',1)
df_train["state"]=df_train["state"].replace('Maharashtra',2)
df_train["state"]=df_train["state"].replace('West_Bengal',3)
df_train["state"]=df_train["state"].replace('Bihar',4)
df_train["state"]=df_train["state"].replace('Tamil_Nadu',5)
df_train["state"]=df_train["state"].replace('Madhya_Pradesh',6)
df_train["state"]=df_train["state"].replace('Karnataka',7)
df_train["state"]=df_train["state"].replace('Gujarat',8)
df_train["state"]=df_train["state"].replace('Rajasthan',9)
df_train["state"]=df_train["state"].replace('Jharkhand',10)
df_train["state"]=df_train["state"].replace('Haryana',11)
df_train["state"]=df_train["state"].replace('Telangana',12)
df_train["state"]=df_train["state"].replace('Assam',13)
df_train["state"]=df_train["state"].replace('Kerala',14)
df_train["state"]=df_train["state"].replace('Delhi',15)
df_train["state"]=df_train["state"].replace('Punjab',16)
df_train["state"]=df_train["state"].replace('Odisha',17)
df_train["state"]=df_train["state"].replace('Chhattisgarh',18)
df_train["state"]=df_train["state"].replace('Uttarakhand',19)
df_train["state"]=df_train["state"].replace('Jammu_and_Kashmir',20)
df_train["state"]=df_train["state"].replace('Puducherry',21)
df_train["state"]=df_train["state"].replace('Himachal_Pradesh',22)
df_train["state"]=df_train["state"].replace('Mizoram',23)
df_train["state"]=df_train["state"].replace('Manipur',24)
df_train["state"]=df_train["state"].replace('Tripura',25)
df_train["state"]=df_train["state"].replace('Uttar_Pradesh[5]',26)
df_train["state"]=df_train["state"].replace('Chandigarh',27)
df_train["state"]=df_train["state"].replace('Sikkim',28)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators =500, random_state=0)
clf.fit(df_train,df_train_output)
y_pred=clf.predict(df_train)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_pred,df_train_output))
# Out:
# Accuracy: 1.0

# %%
j=0
for i in y_pred:
  if (i==1):
    j=j+1
print(j)
k=0
for i in df_train_output:
  if(i==1):
    k=k+1
print(k)
# Out:
# 6142
# 6142

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(df_train_output,y_pred))
print(classification_report(df_train_output,y_pred))
print(accuracy_score(df_train_output, y_pred))
# Out:
# [[42354  1504]
#  [ 1232  4910]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     43858
#            1       0.77      0.80      0.78      6142
#
#     accuracy                           0.95     50000
#    macro avg       0.87      0.88      0.88     50000
# weighted avg       0.95      0.95      0.95     50000
#
# 0.94528

# %%
df_train1=df_testing[["Id","income","age","experience","profession","state","house_ownership","married","car_ownership","current_job_years","current_house_years"]]

# %%
df_train1['married'] = df_train1['married'].replace('married', 1)
df_train1['married'] = df_train1['married'].replace('single', 0)
df_train1['house_ownership'] = df_train1['house_ownership'].replace('owned', 1)
df_train1['house_ownership'] = df_train1['house_ownership'].replace('rented', 0)
df_train1['house_ownership'] = df_train1['house_ownership'].replace('norent_noown', 2)
df_train1['car_ownership'] = df_train1['car_ownership'].replace('no', 0)
df_train1['car_ownership'] = df_train1['car_ownership'].replace('yes', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train1["profession"]=df_train1["profession"].replace('Statistician',0)
df_train1["profession"]=df_train1["profession"].replace('Physician',1)
df_train1["profession"]=df_train1["profession"].replace('Psychologist',2)
df_train1["profession"]=df_train1["profession"].replace('Graphic_Designer',3)
df_train1["profession"]=df_train1["profession"].replace('Industrial_Engineer',4)
df_train1["profession"]=df_train1["profession"].replace('Computer_hardware_engineer',5)
df_train1["profession"]=df_train1["profession"].replace('Flight_attendant',6)
df_train1["profession"]=df_train1["profession"].replace('Financial_Analyst',7)
df_train1["profession"]=df_train1["profession"].replace('Web_designer',8)
df_train1["profession"]=df_train1["profession"].replace('Mechanical_engineer',9)
df_train1["profession"]=df_train1["profession"].replace('Magistrate',10)
df_train1["profession"]=df_train1["profession"].replace('Chemical_engineer',11)
df_train1["profession"]=df_train1["profession"].replace('Comedian',12)
df_train1["profession"]=df_train1["profession"].replace('Drafter',13)
df_train1["profession"]=df_train1["profession"].replace('Biomedical_Engineer',14)
df_train1["profession"]=df_train1["profession"].replace('Fashion_Designer',15)
df_train1["profession"]=df_train1["profession"].replace('Hotel_Manager',16)
df_train1["profession"]=df_train1["profession"].replace('Software_Developer',17)
df_train1["profession"]=df_train1["profession"].replace('Police_officer',18)
df_train1["profession"]=df_train1["profession"].replace('Technical_writer',19)
df_train1["profession"]=df_train1["profession"].replace('Petroleum_Engineer',20)
df_train1["profession"]=df_train1["profession"].replace('Air_traffic_controller',21)
df_train1["profession"]=df_train1["profession"].replace('Artist',22)
df_train1["profession"]=df_train1["profession"].replace('Politician',23)
df_train1["profession"]=df_train1["profession"].replace('Microbiologist',24)
df_train1["profession"]=df_train1["profession"].replace('Secretary',25)
df_train1["profession"]=df_train1["profession"].replace('Computer_operator',26)
df_train1["profession"]=df_train1["profession"].replace('Surgeon',27)
df_train1["profession"]=df_train1["profession"].replace('Consultant',28)
df_train1["profession"]=df_train1["profession"].replace('Aviator',29)
df_train1["profession"]=df_train1["profession"].replace('Lawyer',30)
df_train1["profession"]=df_train1["profession"].replace('Design_Engineer',31)
df_train1["profession"]=df_train1["profession"].replace('Scientist',32)
df_train1["profession"]=df_train1["profession"].replace('Librarian',33)
df_train1["profession"]=df_train1["profession"].replace('Architect',34)
df_train1["profession"]=df_train1["profession"].replace('Technician',35)
df_train1["profession"]=df_train1["profession"].replace('Chef',36)
df_train1["profession"]=df_train1["profession"].replace('Technology_specialist',37)
df_train1["profession"]=df_train1["profession"].replace('Geologist',38)
df_train1["profession"]=df_train1["profession"].replace('Army_officer',39)
df_train1["profession"]=df_train1["profession"].replace('Economist',40)
df_train1["profession"]=df_train1["profession"].replace('Dentist',41)
df_train1["profession"]=df_train1["profession"].replace('Designer',42)
df_train1["profession"]=df_train1["profession"].replace('Surveyor',43)
df_train1["profession"]=df_train1["profession"].replace('Analyst',44)
df_train1["profession"]=df_train1["profession"].replace('Chartered_Accountant',45)
df_train1["profession"]=df_train1["profession"].replace('Firefighter',46)
df_train1["profession"]=df_train1["profession"].replace('Civil_servant',47)
df_train1["profession"]=df_train1["profession"].replace('Official',48)
df_train1["profession"]=df_train1["profession"].replace('Civil_engineer',49)
df_train1["profession"]=df_train1["profession"].replace('Engineer',50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train1["state"]=df_train1["state"].replace('Uttar_Pradesh',0)
df_train1["state"]=df_train1["state"].replace('Andhra_Pradesh',1)
df_train1["state"]=df_train1["state"].replace('Maharashtra',2)
df_train1["state"]=df_train1["state"].replace('West_Bengal',3)
df_train1["state"]=df_train1["state"].replace('Bihar',4)
df_train1["state"]=df_train1["state"].replace('Tamil_Nadu',5)
df_train1["state"]=df_train1["state"].replace('Madhya_Pradesh',6)
df_train1["state"]=df_train1["state"].replace('Karnataka',7)
df_train1["state"]=df_train1["state"].replace('Gujarat',8)
df_train1["state"]=df_train1["state"].replace('Rajasthan',9)
df_train1["state"]=df_train1["state"].replace('Jharkhand',10)
df_train1["state"]=df_train1["state"].replace('Haryana',11)
df_train1["state"]=df_train1["state"].replace('Telangana',12)
df_train1["state"]=df_train1["state"].replace('Assam',13)
df_train1["state"]=df_train1["state"].replace('Kerala',14)
df_train1["state"]=df_train1["state"].replace('Delhi',15)
df_train1["state"]=df_train1["state"].replace('Punjab',16)
df_train1["state"]=df_train1["state"].replace('Odisha',17)
df_train1["state"]=df_train1["state"].replace('Chhattisgarh',18)
df_train1["state"]=df_train1["state"].replace('Uttarakhand',19)
df_train1["state"]=df_train1["state"].replace('Jammu_and_Kashmir',20)
df_train1["state"]=df_train1["state"].replace('Puducherry',21)
df_train1["state"]=df_train1["state"].replace('Himachal_Pradesh',22)
df_train1["state"]=df_train1["state"].replace('Mizoram',23)
df_train1["state"]=df_train1["state"].replace('Manipur',24)
df_train1["state"]=df_train1["state"].replace('Tripura',25)
df_train1["state"]=df_train1["state"].replace('Uttar_Pradesh[5]',26)
df_train1["state"]=df_train1["state"].replace('Chandigarh',27)
df_train1["state"]=df_train1["state"].replace('Sikkim',28)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test_pred=clf.predict(df_train1)

# %%
k=0
for i in test_pred:
  if (i==1):
    k=k+1
print(k)
# Out:
# 2514

# %%
dict = {"Id":df_testing.Id, "risk_flag": test_pred}
df = pd.DataFrame(dict)
df.to_csv("submission24.csv")
